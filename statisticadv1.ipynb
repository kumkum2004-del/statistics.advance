# %% [markdown]
# # ques.1 What is a random variable in probability theory?
#   - In probability theory, a random variable is a variable that takes on different values based on the outcome of a random event or experiment.
#
# #ques2. What are the types of random variables?
#   - 1. Discrete Random Variable
#     - Definition: Takes on a countable number of distinct values.
#   - 2. Continuous Random Variable
#     - Definition: Takes on any value within a range, usually involving real numbers.
#
# #ques 3. What is the difference between discrete and continuous distributions?
#   - Discrete Distribution
#     - Deals with discrete random variables.
#     - Takes countable values (e.g., 0, 1, 2, 3...).
#     - Example: Number of heads in 3 coin tosses.
#   - Continuous Distribution
#     - Deals with continuous random variables.
#     - Takes uncountable/infinite values in a range (e.g., 2.1, 3.56...).
#     - Example: Time taken to run a race.
#
#
# #ques 4. What are probability distribution functions (PDF)?
#   - A Probability Distribution Function (PDF) describes how probabilities are distributed over the values of a random variable.
#     - For Discrete Random Variables:
#       - The function is called a Probability Mass Function (PMF).
#     - For Continuous Random Variables:
#       - The function is called a Probability Density Function (PDF).
#
# #ques. 5 How do cumulative distribution functions (CDF) differ from probability distribution functions (PDF).
#   -  1. Probability Distribution Function (PDF / PMF)
#     - Shows the likelihood of a specific value.
#   - 2. Cumulative Distribution Function (CDF)
#     - Shows the cumulative probability up to a value.
#
# #ques 6.What is a discrete uniform distribution?
#   - A discrete uniform distribution is a type of probability distribution where all outcomes are equally likely.
#
# #ques. 7  What are the key properties of a Bernoulli distribution?
#   - The Bernoulli distribution is one of the simplest and most important probability distributions in statistics and machine learning. It models a random experiment with exactly two outcomes: success (1) and failure (0).
#
# #ques. 8 What is the binomial distribution, and how is it used in probability?
#   - The binomial distribution is a fundamental probability distribution that describes the number of successes in a fixed number of independent trials, where each trial has only two possible outcomes — success or failure.
#
# #ques.9 What is the Poisson distribution and where is it applied.
#   - The Poisson distribution is a probability distribution that models the number of times an event occurs in a fixed interval of time or space, given a known constant average rate, and assuming the events occur independently.
#
# #ques.10  What is a continuous uniform distribution?
#   - The continuous uniform distribution is a probability distribution where all outcomes in a given interval are equally likely. It's one of the simplest continuous probability distributions.
#
# #ques.11 What are the characteristics of a normal distribution?
#   - Key Characteristics of a Normal Distribution:
#     - bell-shaped-curve
#     - symmytricity
#     - mean= mode= median
#
# #ques.12  What is the standard normal distribution, and why is it important?
#   - The standard normal distribution is a special case of the normal distribution that has:
#      - Mean (𝜇) = 0
#      - Standard deviation (σ) = 1
#
# #ques.13 What is the Central Limit Theorem (CLT), and why is it critical in statistics?
#   - The Central Limit Theorem (CLT) is one of the most important theorems in statistics. It explains why normal distributions are so common and powerful in data analysis.
#
# #ques.14 How does the Central Limit Theorem relate to the normal distribution?
#   - Even if the original data is not normally distributed, the distribution of sample means becomes approximately normal as the sample size increases,
#
# #ques. 15 What is the application of Z statistics in hypothesis testing?
#   - The Z statistic measures how many standard deviations a sample mean (or observed value) is away from the population mean under the null hypothesis.
#
# #ques . 16 How do you calculate a Z-score, and what does it represent?
#   - A Z-score tells you how many standard deviations a value is away from the mean of its distribution.It standardizes values, so you can compare data points from different distributions or find probabilities using the standard normal distribution.
#
# #ques 17What are point estimates and interval estimates in statistics?
#   -  Point Estimate:
#      - A point estimate is a single value that is used as an estimate of a population parameter.
#   - Interval Estimate:
#      - An interval estimate gives a range of values within which the population parameter is expected to lie.
#
# #ques. 18 What is the significance of confidence intervals in statistical analysis?
#   - Confidence intervals tell you where the true value probably lies and how confident you can be about your estimate.
#
# #ques. 19 What is the relationship between a Z-score and a confidence interval?
#   - Confidence intervals are built around a sample estimate (like a mean), using a Z-score to capture the desired level of confidence.
#
# #ques 20 How are Z-scores used to compare different distributions?
#   - Z-scores convert raw data points into a common scale by measuring how many standard deviations each value is from its own mean.
#
# #ques 21 What are the assumptions for applying the Central Limit Theorem?
#   - ramdom sampling
#     - samples must be random.
#   - sample size
#     - sample size mmust be large.
#   - indepandence
#     - sample values must be independent to each other.
#
#
# #ques 22 What is the concept of expected value in a probability distribution?
#   - The expected value (EV) is the long-run average or mean value you would expect if you repeated a random experiment many times.
#
# #ques 23  How does a probability distribution relate to the expected outcome of a random variable?
#   - Probability Distribution:
#       - It describes all possible values a random variable can take and the probabilities associated with those values.
#   - expected value: The expected value is the long-run average or mean value you would expect if you repeated a random experiment many times.
